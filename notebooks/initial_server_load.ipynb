# %%
#dependencies
import pandas as pd
from sqlalchemy import engine

# %%
#Read in initial.csv
df = pd.read_csv(r'../Resources/initial.csv')
df.head()
# Out:
#                                             post_url  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3  https://www.indeed.com/rc/clk?jk=bddcb1faeb174...
# 4  https://www.indeed.com/rc/clk?jk=85cc3860e666f...
#
#                               job_title                        company  \
# 0                      Data Scientist -                       Blue Owl
# 1                        Data Scientist        ClientSolv Technologies
# 2                       Statistician II                        Aerotek
# 3  Data Scientist - Production Research                  RiceTec, Inc.
# 4         Remote Sensing Data Scientist  University of Texas at Austin
#
#             city state                  date_added  \
# 0  San Francisco    CA  2020-06-23 13:00:07.222933
# 1      Englewood    CO  2020-06-23 13:00:07.232569
# 2  North Chicago    IL  2020-06-23 13:00:07.245375
# ...

# %%
#create tables from df

# %%
#master table
master_df = df[['job_title', 'company', 'salary_range', 'abstract', 'post_url', 'date_added', 'city', 'state']]
master_df.head()
# Out:
#                               job_title                        company  \
# 0                      Data Scientist -                       Blue Owl
# 1                        Data Scientist        ClientSolv Technologies
# 2                       Statistician II                        Aerotek
# 3  Data Scientist - Production Research                  RiceTec, Inc.
# 4         Remote Sensing Data Scientist  University of Texas at Austin
#
#                  salary_range  \
# 0  $250,000 - $375,000 a year
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                             abstract  \
# 0  We’re using rich customer insights, advanced t...
# 1  Experience with some machine learning methodol...
# 2  Study Preparation: Meets with CRA, R&D, Instru...
# 3  The RiceTec Data Scientist will need to Design...
# 4  Demonstrated experience and familiarity in wor...
#
# ...

# %%
#job source table
job_source_df = df[['']]

# %%
#Connect to sql server INSERT DB NAME
rds_connection_string = "postgres:password@35.193.2.240:5432/"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Load into ___ table
_df.to_sql(name='_____', con=engine, if_exists='append', index=False)

# %%
#Load into ___ table
_df.to_sql(name='_____', con=engine, if_exists='append', index=False)

# %%
#Load into ___ table
_df.to_sql(name='_____', con=engine, if_exists='append', index=False)

# %%
#Load into ___ table
_df.to_sql(name='_____', con=engine, if_exists='append', index=False)
